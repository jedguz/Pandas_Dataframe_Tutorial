# %% [markdown]
# # Lets Learn Pandas!

# %%
import pandas as pd
import os

# %%
## Recall, to check functions utility use '?'. For example, ?biopics.rename
## Also, note [0:10] is added to many inputs to make sure only a sample of the resulting the table is only previewed

# %% [markdown]
# ## 1. Importing '.csv' as a Dataframe and Reading

# %% [markdown]
# #### To create a relative directory, first ask which directory are we operating in?

# %%
## Print the current working directory 

os.getcwd()
# Out:
# 'C:\\Users\\jguze\\Documents\\Jupyter'

# %% [markdown]
# #### Now, specify the csv relative to this directory. Note that '..' means go back one folder

# %%
## So, this means go back to documents, into documents\data\biopics.csv

biopics = pd.read_csv("../data/biopics.csv", encoding="latin-1")

# %%
## Check we have a pd dataframe

type(biopics)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Note, when importing .txt documents, include the argument 'delimiter=...' to indicate to pandas where the new value begins, because its not given that delimiter=',' like in comma seperated value files

# %% [markdown]
# ## 2. Reading a Dataframe

# %% [markdown]
# #### It's important to have a good understanding of the data, and check everything imported as expected. Here we introduce '.loc' and '.iloc', which can be throught of as row filtering (or ***non***-filtering) functions and are extremely useful

# %%
## Check data looks as expected

biopics.head()
# Out:
#                  title country  year_release  box_office type_of_subject  \
# 0  10 Rillington Place      UK          1971         NaN        Criminal
# 1     12 Years a Slave   US/UK          2013  56700000.0           Other
# 2            127 Hours   US/UK          2010  18300000.0         Athlete
# 3                 1987  Canada          2014         NaN           Other
# 4             20 Dates      US          1998    537000.0           Other
#
#      lead_actor_actress
# 0  Richard Attenborough
# 1      Chiwetel Ejiofor
# 2          James Franco
# 3     Jean-Carl Boucher
# 4       Myles Berkowitz

# %%
## biopics.columns returns an object of index type containing the column names (axis labels). An immutable array 
## implementing an ordered, sliceable set. In other words it can't be altered directly through '.columns'.

print(biopics.columns)
# Out:
# Index(['title', 'country', 'year_release', 'box_office', 'type_of_subject',
#        'lead_actor_actress'],
#       dtype='object')

# %% [markdown]
# #### To check particular columns (based on col name)...

# %%
biopics[['title']][0:10]
# Out:
#                    title
# 0    10 Rillington Place
# 1       12 Years a Slave
# 2              127 Hours
# 3                   1987
# 4               20 Dates
# 5                     21
# 6   24 Hour Party People
# 7                     42
# 8              8 Seconds
# 9  84 Charing Cross Road

# %%
## We can also check multiple columns by specifying them in a list

biopics[['title','year_release']][0:10]
# Out:
#                    title  year_release
# 0    10 Rillington Place          1971
# 1       12 Years a Slave          2013
# 2              127 Hours          2010
# 3                   1987          2014
# 4               20 Dates          1998
# 5                     21          2008
# 6   24 Hour Party People          2002
# 7                     42          2013
# 8              8 Seconds          1994
# 9  84 Charing Cross Road          1987

# %% [markdown]
# #### To check particular rows (based on index #)...

# %%
## Use '.iloc' function, standing for index location, noting that pd assigns an integer to each row starting at 0

biopics.iloc[0:10]
# Out:
#                    title country  year_release  box_office type_of_subject  \
# 0    10 Rillington Place      UK          1971         NaN        Criminal
# 1       12 Years a Slave   US/UK          2013  56700000.0           Other
# 2              127 Hours   US/UK          2010  18300000.0         Athlete
# 3                   1987  Canada          2014         NaN           Other
# 4               20 Dates      US          1998    537000.0           Other
# 5                     21      US          2008  81200000.0           Other
# 6   24 Hour Party People      UK          2002   1130000.0        Musician
# 7                     42      US          2013  95000000.0         Athlete
# 8              8 Seconds      US          1994  19600000.0         Athlete
# 9  84 Charing Cross Road   US/UK          1987   1080000.0          Author
#
#      lead_actor_actress
# 0  Richard Attenborough
# 1      Chiwetel Ejiofor
# 2          James Franco
# 3     Jean-Carl Boucher
# 4       Myles Berkowitz
# 5          Jim Sturgess
# 6          Steve Coogan
# 7      Chadwick Boseman
# 8            Luke Perry
# 9       Anthony Hopkins

# %%
## Also can look for specific columns of specific rows by slicing

biopics.iloc[0:10,0:3]
# Out:
#                    title country  year_release
# 0    10 Rillington Place      UK          1971
# 1       12 Years a Slave   US/UK          2013
# 2              127 Hours   US/UK          2010
# 3                   1987  Canada          2014
# 4               20 Dates      US          1998
# 5                     21      US          2008
# 6   24 Hour Party People      UK          2002
# 7                     42      US          2013
# 8              8 Seconds      US          1994
# 9  84 Charing Cross Road   US/UK          1987

# %% [markdown]
# #### To check rows based on their characteristics/entries...

# %%
## Use '.loc' function to access rows/cols based on labels as opposed to strictly integer index. Also works for boolean arrays
## strictly the same length as row axis. Here is a boolean example

biopics.loc[biopics['year_release']<=1929]

## Inside the bracket we have a list of booleans with each each entry corresponding to an integer index location
# Out:
#                  title country  year_release  box_office type_of_subject  \
# 176           Disraeli      US          1929         NaN    World leader
# 453       Regeneration      US          1915         NaN           Other
# 606  The King of Kings      US          1927         NaN      Historical
#
#      lead_actor_actress
# 176       George Arliss
# 453  Rockliffe Fellowes
# 606         H.B. Warner

# %%
## We can also specify which columns to show

biopics.loc[biopics['country'] == 'UK', ['title', 'country']][0:10]
# Out:
#                          title country
# 0          10 Rillington Place      UK
# 6         24 Hour Party People      UK
# 17       A Man for All Seasons      UK
# 42        An Angel at My Table      UK
# 47             Another Country      UK
# 52                      Baader      UK
# 53                    Backbeat      UK
# 54                    Backbeat      UK
# 55                Bandit Queen      UK
# 58  Bathory: Countess of Blood      UK

# %% [markdown]
# ## 3. Describing and Sorting Dataframe

# %%
## For a brief analysis use '.describe()'. In this case, it is not very useful as its mostly categorical data

biopics.describe()
# Out:
#        year_release    box_office
# count    763.000000  4.390000e+02
# mean    1986.971166  2.295256e+07
# std       24.020315  3.824200e+07
# min     1915.000000  3.150000e+03
# 25%     1969.000000  1.160000e+06
# 50%     1995.000000  6.140000e+06
# 75%     2007.000000  3.050000e+07
# max     2014.000000  3.500000e+08

# %%
## For sorting, use function '.sort_values'. The attribute 'by' is necessary when using sort_values

biopics.sort_values(by='title')[0:10]
# Out:
#                    title country  year_release  box_office type_of_subject  \
# 0    10 Rillington Place      UK          1971         NaN        Criminal
# 1       12 Years a Slave   US/UK          2013  56700000.0           Other
# 2              127 Hours   US/UK          2010  18300000.0         Athlete
# 3                   1987  Canada          2014         NaN           Other
# 4               20 Dates      US          1998    537000.0           Other
# 5                     21      US          2008  81200000.0           Other
# 6   24 Hour Party People      UK          2002   1130000.0        Musician
# 7                     42      US          2013  95000000.0         Athlete
# 8              8 Seconds      US          1994  19600000.0         Athlete
# 9  84 Charing Cross Road   US/UK          1987   1080000.0          Author
#
#      lead_actor_actress
# 0  Richard Attenborough
# 1      Chiwetel Ejiofor
# 2          James Franco
# 3     Jean-Carl Boucher
# 4       Myles Berkowitz
# 5          Jim Sturgess
# 6          Steve Coogan
# 7      Chadwick Boseman
# 8            Luke Perry
# 9       Anthony Hopkins

# %%
## Can sort by descending year, followed by title. Note, not specifying ascending defaults to 'True'

biopics.sort_values(by=['year_release','title'], ascending=[False, True])[0:10]
# Out:
#                       title    country  year_release   box_office  \
# 3                      1987     Canada          2014          NaN
# 38          American Sniper         US          2014  350000000.0
# 72                 Big Eyes  US/Canada          2014   14500000.0
# 125            Cesar Chavez         US          2014    5550000.0
# 162           Desert Dancer         UK          2014     144000.0
# 173   Digging Up the Marrow         US          2014          NaN
# 198  Exodus: Gods and Kings         UK          2014   65000000.0
# 210              Foxcatcher         US          2014   12100000.0
# 225               Get on Up      US/UK          2014   30500000.0
# 237         Grace of Monaco         US          2014          NaN
#
#     type_of_subject lead_actor_actress
# 3             Other  Jean-Carl Boucher
# 38         Military     Bradley Cooper
# 72           Artist          Amy Adams
# 125        Activist      Michael PeÌ±a
# 162          Artist      Reece Ritchie
# 173           Other         Adam Green
# 198      Historical     Christian Bale
# 210         Athlete     Channing Tatum
# 225          Singer   Chadwick Boseman
# 237         Actress      Nicole Kidman

# %%
## Can also place NA values at the top, as follows. So in this case, NA->highest->lowest

biopics.sort_values(by='box_office', ascending=False, na_position='first')[0:600:50]
# Out:
#                                  title    country  year_release  box_office  \
# 0                  10 Rillington Place         UK          1971         NaN
# 137                          Cleopatra         US          1934         NaN
# 261          Hitler: The Last Ten Days         UK          1973         NaN
# 395                       My Childhood         UK          1972         NaN
# 532       The Assassination of Trotsky         UK          1972         NaN
# 617                  The Lawless Breed         US          1953         NaN
# 711                 To Walk with Lions  Canada/UK          1999         NaN
# 477                   Schindler's List         US          1993  96100000.0
# 438                      Private Parts         US          1997  41200000.0
# 218                              Frida  US/Canada          2002  25800000.0
# 249                       Henry & June         US          1990  11600000.0
# 562  The Diving Bell and the Butterfly         US          2007   5990000.0
#
#     type_of_subject    lead_actor_actress
# 0          Criminal  Richard Attenborough
# 137      Historical     Claudette Colbert
# 261        Military         Alec Guinness
# 395           Other     Stephen Archibald
# 532        Activist        Richard Burton
# 617        Criminal           Rock Hudson
# 711           Other           John Michie
# 477           Other           Liam Neeson
# 438           Media          Howard Stern
# 218          Artist           Salma Hayek
# 249          Author             Fred Ward
# 562           Media       Mathieu Amalric

# %% [markdown]
# ## 4. Adding/Dropping/Editing a Column

# %% [markdown]
# #### Adding columns by 'operations on existing columns'

# %%
## There are many way to add columns to our dataframe. An example is as follows, noting '|' is 'or'

biopics['UK or US/UK'] = (biopics['country'] == 'UK') | (biopics['country'] == 'US/UK')
biopics[0:10]
# Out:
#                    title country  year_release  box_office type_of_subject  \
# 0    10 Rillington Place      UK          1971         NaN        Criminal
# 1       12 Years a Slave   US/UK          2013  56700000.0           Other
# 2              127 Hours   US/UK          2010  18300000.0         Athlete
# 3                   1987  Canada          2014         NaN           Other
# 4               20 Dates      US          1998    537000.0           Other
# 5                     21      US          2008  81200000.0           Other
# 6   24 Hour Party People      UK          2002   1130000.0        Musician
# 7                     42      US          2013  95000000.0         Athlete
# 8              8 Seconds      US          1994  19600000.0         Athlete
# 9  84 Charing Cross Road   US/UK          1987   1080000.0          Author
#
#      lead_actor_actress  UK or US/UK
# 0  Richard Attenborough         True
# 1      Chiwetel Ejiofor         True
# 2          James Franco         True
# 3     Jean-Carl Boucher        False
# 4       Myles Berkowitz        False
# 5          Jim Sturgess        False
# 6          Steve Coogan         True
# 7      Chadwick Boseman        False
# 8            Luke Perry        False
# 9       Anthony Hopkins         True

# %% [markdown]
# #### Adding columns at lower-level and more efficiently

# %%
## If for some reason we wished to add a column summing release year and box office, we can use '.iloc'

biopics['Year + Box office'] = biopics.iloc[:, 2:4].sum(axis=1)
biopics[0:10]

## Here ' : ' specifies every row, and .sum(axis=1) means sum left to right (not up and down)
# Out:
#                    title country  year_release  box_office type_of_subject  \
# 0    10 Rillington Place      UK          1971         NaN        Criminal
# 1       12 Years a Slave   US/UK          2013  56700000.0           Other
# 2              127 Hours   US/UK          2010  18300000.0         Athlete
# 3                   1987  Canada          2014         NaN           Other
# 4               20 Dates      US          1998    537000.0           Other
# 5                     21      US          2008  81200000.0           Other
# 6   24 Hour Party People      UK          2002   1130000.0        Musician
# 7                     42      US          2013  95000000.0         Athlete
# 8              8 Seconds      US          1994  19600000.0         Athlete
# 9  84 Charing Cross Road   US/UK          1987   1080000.0          Author
#
#      lead_actor_actress  UK or US/UK  Year + Box office
# 0  Richard Attenborough         True             1971.0
# 1      Chiwetel Ejiofor         True         56702013.0
# 2          James Franco         True         18302010.0
# 3     Jean-Carl Boucher        False             2014.0
# 4       Myles Berkowitz        False           538998.0
# 5          Jim Sturgess        False         81202008.0
# 6          Steve Coogan         True          1132002.0
# 7      Chadwick Boseman        False         95002013.0
# 8            Luke Perry        False         19601994.0
# 9       Anthony Hopkins         True          1081987.0

# %% [markdown]
# #### Dropping columns using '.drop'

# %%
## For dropping rows and columns we use the '.drop' fucntion. If unspecified, the fucntion drops rows, so we specify.
## As an example, if we want to drop the column 'UK or US/UK' and 'lead_actor_actress'

biopics.drop(columns=['UK or US/UK', 'lead_actor_actress'])[0:10]
# Out:
#                    title country  year_release  box_office type_of_subject  \
# 0    10 Rillington Place      UK          1971         NaN        Criminal
# 1       12 Years a Slave   US/UK          2013  56700000.0           Other
# 2              127 Hours   US/UK          2010  18300000.0         Athlete
# 3                   1987  Canada          2014         NaN           Other
# 4               20 Dates      US          1998    537000.0           Other
# 5                     21      US          2008  81200000.0           Other
# 6   24 Hour Party People      UK          2002   1130000.0        Musician
# 7                     42      US          2013  95000000.0         Athlete
# 8              8 Seconds      US          1994  19600000.0         Athlete
# 9  84 Charing Cross Road   US/UK          1987   1080000.0          Author
#
#    Year + Box office
# 0             1971.0
# 1         56702013.0
# 2         18302010.0
# 3             2014.0
# 4           538998.0
# 5         81202008.0
# 6          1132002.0
# 7         95002013.0
# 8         19601994.0
# 9          1081987.0

# %%
## Equivalently, can specify labels and the axis as opposed to 'columns=[...]'

biopics.drop(axis=1, labels=['UK or US/UK', 'lead_actor_actress'])[0:10]
# Out:
#                    title country  year_release  box_office type_of_subject  \
# 0    10 Rillington Place      UK          1971         NaN        Criminal
# 1       12 Years a Slave   US/UK          2013  56700000.0           Other
# 2              127 Hours   US/UK          2010  18300000.0         Athlete
# 3                   1987  Canada          2014         NaN           Other
# 4               20 Dates      US          1998    537000.0           Other
# 5                     21      US          2008  81200000.0           Other
# 6   24 Hour Party People      UK          2002   1130000.0        Musician
# 7                     42      US          2013  95000000.0         Athlete
# 8              8 Seconds      US          1994  19600000.0         Athlete
# 9  84 Charing Cross Road   US/UK          1987   1080000.0          Author
#
#    Year + Box office
# 0             1971.0
# 1         56702013.0
# 2         18302010.0
# 3             2014.0
# 4           538998.0
# 5         81202008.0
# 6          1132002.0
# 7         95002013.0
# 8         19601994.0
# 9          1081987.0

# %%
## Now lets actually drop the useless 'Year + Box office' column. Notice, now we assign the change

biopics = biopics.drop(columns='Year + Box office')
biopics[0:10]
# Out:
#                    title country  year_release  box_office type_of_subject  \
# 0    10 Rillington Place      UK          1971         NaN        Criminal
# 1       12 Years a Slave   US/UK          2013  56700000.0           Other
# 2              127 Hours   US/UK          2010  18300000.0         Athlete
# 3                   1987  Canada          2014         NaN           Other
# 4               20 Dates      US          1998    537000.0           Other
# 5                     21      US          2008  81200000.0           Other
# 6   24 Hour Party People      UK          2002   1130000.0        Musician
# 7                     42      US          2013  95000000.0         Athlete
# 8              8 Seconds      US          1994  19600000.0         Athlete
# 9  84 Charing Cross Road   US/UK          1987   1080000.0          Author
#
#      lead_actor_actress  UK or US/UK
# 0  Richard Attenborough         True
# 1      Chiwetel Ejiofor         True
# 2          James Franco         True
# 3     Jean-Carl Boucher        False
# 4       Myles Berkowitz        False
# 5          Jim Sturgess        False
# 6          Steve Coogan         True
# 7      Chadwick Boseman        False
# 8            Luke Perry        False
# 9       Anthony Hopkins         True

# %% [markdown]
# #### Editing columns

# %%
## Suppose we want to convert box_office to millions of dollars, and rename it to 'revenue (mil)'. Similairly to before,
## we can specify columns=dict_object OR axis=1 and mapper=dict_object

biopics['box_office'] = biopics['box_office']/1000000
biopics = biopics.rename(columns={'box_office':'revenue (mil)'})
biopics[0:10]
# Out:
#                    title country  year_release  revenue (mil) type_of_subject  \
# 0    10 Rillington Place      UK          1971            NaN        Criminal
# 1       12 Years a Slave   US/UK          2013         56.700           Other
# 2              127 Hours   US/UK          2010         18.300         Athlete
# 3                   1987  Canada          2014            NaN           Other
# 4               20 Dates      US          1998          0.537           Other
# 5                     21      US          2008         81.200           Other
# 6   24 Hour Party People      UK          2002          1.130        Musician
# 7                     42      US          2013         95.000         Athlete
# 8              8 Seconds      US          1994         19.600         Athlete
# 9  84 Charing Cross Road   US/UK          1987          1.080          Author
#
#      lead_actor_actress  UK or US/UK
# 0  Richard Attenborough         True
# 1      Chiwetel Ejiofor         True
# 2          James Franco         True
# 3     Jean-Carl Boucher        False
# 4       Myles Berkowitz        False
# 5          Jim Sturgess        False
# 6          Steve Coogan         True
# 7      Chadwick Boseman        False
# 8            Luke Perry        False
# 9       Anthony Hopkins         True

# %%
## Additionally, we can change the order of columns, which is purely visual but sometimes useful

biopics = biopics[['title','type_of_subject','lead_actor_actress','revenue (mil)','country','year_release']]
biopics[0:10]
# Out:
#                    title type_of_subject    lead_actor_actress  revenue (mil)  \
# 0    10 Rillington Place        Criminal  Richard Attenborough            NaN
# 1       12 Years a Slave           Other      Chiwetel Ejiofor         56.700
# 2              127 Hours         Athlete          James Franco         18.300
# 3                   1987           Other     Jean-Carl Boucher            NaN
# 4               20 Dates           Other       Myles Berkowitz          0.537
# 5                     21           Other          Jim Sturgess         81.200
# 6   24 Hour Party People        Musician          Steve Coogan          1.130
# 7                     42         Athlete      Chadwick Boseman         95.000
# 8              8 Seconds         Athlete            Luke Perry         19.600
# 9  84 Charing Cross Road          Author       Anthony Hopkins          1.080
#
#   country  year_release
# 0      UK          1971
# 1   US/UK          2013
# 2   US/UK          2010
# 3  Canada          2014
# 4      US          1998
# 5      US          2008
# 6      UK          2002
# 7      US          2013
# 8      US          1994
# 9   US/UK          1987

# %% [markdown]
# ## 5. Filtering Dataframe Rows

# %% [markdown]
# #### Removing rows based on index

# %%
## This is straightforward and we use '.drop'

biopics.drop(index=range(15), columns='title')[0:10]
# Out:
#    type_of_subject lead_actor_actress  revenue (mil) country  year_release
# 15           Other        Kathy Bates           1.70      US          1993
# 16           Other       Richard Todd            NaN      US          1955
# 17      Historical      Paul Scofield            NaN      UK          1966
# 18         Actress     PenÌ©lope Cruz            NaN   US/UK          2008
# 19         Athlete       Adrien Brody            NaN   US/UK          2008
# 20      Journalist      Dan Futterman           9.17   US/UK          2007
# 21      Journalist     Angelina Jolie           9.17   US/UK          2007
# 22        Musician       Cornel Wilde            NaN      US          1945
# 23    World leader     Raymond Massey            NaN      US          1940
# 24        Military      Robert Taylor            NaN      US          1952

# %% [markdown]
# #### Removing rows based on conditions

# %%
## Suppose we want to remove films (rows) where revenue is 'NaN' and the country is US. First create boolean list of films where
## such films correspond to 'False'

index_to_keep = ~ ( (biopics['revenue (mil)'].isna()) & (biopics['country'] == 'US') )
index_to_keep
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 758    False
# 759    False
# 760    False
# 761    False
# 762    False
# Length: 763, dtype: bool

# %%
biopics = biopics.loc[index_to_keep]
biopics[0:10]
# Out:
#                    title type_of_subject    lead_actor_actress  revenue (mil)  \
# 0    10 Rillington Place        Criminal  Richard Attenborough            NaN
# 1       12 Years a Slave           Other      Chiwetel Ejiofor         56.700
# 2              127 Hours         Athlete          James Franco         18.300
# 3                   1987           Other     Jean-Carl Boucher            NaN
# 4               20 Dates           Other       Myles Berkowitz          0.537
# 5                     21           Other          Jim Sturgess         81.200
# 6   24 Hour Party People        Musician          Steve Coogan          1.130
# 7                     42         Athlete      Chadwick Boseman         95.000
# 8              8 Seconds         Athlete            Luke Perry         19.600
# 9  84 Charing Cross Road          Author       Anthony Hopkins          1.080
#
#   country  year_release
# 0      UK          1971
# 1   US/UK          2013
# 2   US/UK          2010
# 3  Canada          2014
# 4      US          1998
# 5      US          2008
# 6      UK          2002
# 7      US          2013
# 8      US          1994
# 9   US/UK          1987

# %% [markdown]
# #### Removing rows based on conditions is hard. Remember,
# #### 1. Create a boolean 'list' with removing condition corresponding to 'False'
# #### 2. Use '.loc' to filter rows based on boolean 'list'

# %% [markdown]
# ## 6. Conditional Changes

# %% [markdown]
# #### Simply specify the rows meeting the condition with '.loc', then find the entries in those rows we wish to change

# %%
## Suppose we wished to change the subject 'Criminal' to 'Crime'

biopics.loc[biopics['type_of_subject'] == 'Criminal', 'type_of_subject'] = 'Crime'
biopics[0:10]
# Out:
#                    title type_of_subject    lead_actor_actress  revenue (mil)  \
# 0    10 Rillington Place           Crime  Richard Attenborough            NaN
# 1       12 Years a Slave           Other      Chiwetel Ejiofor         56.700
# 2              127 Hours         Athlete          James Franco         18.300
# 3                   1987           Other     Jean-Carl Boucher            NaN
# 4               20 Dates           Other       Myles Berkowitz          0.537
# 5                     21           Other          Jim Sturgess         81.200
# 6   24 Hour Party People        Musician          Steve Coogan          1.130
# 7                     42         Athlete      Chadwick Boseman         95.000
# 8              8 Seconds         Athlete            Luke Perry         19.600
# 9  84 Charing Cross Road          Author       Anthony Hopkins          1.080
#
#   country  year_release
# 0      UK          1971
# 1   US/UK          2013
# 2   US/UK          2010
# 3  Canada          2014
# 4      US          1998
# 5      US          2008
# 6      UK          2002
# 7      US          2013
# 8      US          1994
# 9   US/UK          1987

# %%
## Suppose for every movie with 'NaN' in revenue, we wish to add 'NO PREMIERE' to the title

biopics.loc[biopics['revenue (mil)'].isna(),'title'] += ' NO PREMIERE'
biopics[0:10]
# Out:
#                              title type_of_subject    lead_actor_actress  \
# 0  10 Rillington Place NO PREMIERE           Crime  Richard Attenborough
# 1                 12 Years a Slave           Other      Chiwetel Ejiofor
# 2                        127 Hours         Athlete          James Franco
# 3                 1987 NO PREMIERE           Other     Jean-Carl Boucher
# 4                         20 Dates           Other       Myles Berkowitz
# 5                               21           Other          Jim Sturgess
# 6             24 Hour Party People        Musician          Steve Coogan
# 7                               42         Athlete      Chadwick Boseman
# 8                        8 Seconds         Athlete            Luke Perry
# 9            84 Charing Cross Road          Author       Anthony Hopkins
#
#    revenue (mil) country  year_release
# 0            NaN      UK          1971
# 1         56.700   US/UK          2013
# 2         18.300   US/UK          2010
# 3            NaN  Canada          2014
# 4          0.537      US          1998
# 5         81.200      US          2008
# 6          1.130      UK          2002
# 7         95.000      US          2013
# 8         19.600      US          1994
# 9          1.080   US/UK          1987
